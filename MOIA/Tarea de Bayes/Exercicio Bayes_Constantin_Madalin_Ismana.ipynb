# %% [markdown]
# Utiliza el problema de Bayes en un ejemplo clásico: El embarazo de Bayes.
# Comienza así…una tarde, una mujer sospecha que puede estar embarazada. Para estar segura de su estado compra un test de embarazo que sabe tiene una eficacia del 90% en detectar embarazos, además indica en las instrucciones que da falsos positivos el 50% de las veces.
#
# La probabilidad de quedarse embarazada tras mantener relaciones sin protección se supone del 15% :P(E).
#
# La mujer se realiza el test y obtiene un resultado positivo. ¿Cuál es la probabilidad de que dicha mujer esté embarazada?
#
# Como no se cree que está embarazada, vuelve a realizar el test de embarazo y este vuelve a ser positivo y también una tercera vez. Así que después de 3 intentos sí está segura.
#
# Realiza primero los cálculos a mano y después implementa un programa en python que lo resuelva, indicando el % de probabilidad en cada caso de que esté embarazada(hipótesis) siendo los test positivos(evidencia).
#
# Ten en cuenta: una vez que ha realizado un test, se ha de tener en cuenta el resultado obtenido y actualizar P(E) en la siguiente iteración.
# Prueba a realizar el test unas cuantas veces más y represéntalo en una gráfica.

# %% [markdown]
# <h1>Importar las librerias<h1>

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# <h1>Configuramos los parámetros iniciales<h1>

# %%
P_H = 0.15  # Probabilidad inicial de estar embarazada
P_E_H = 0.9  # Probabilidad de un test positivo dado que está embarazada
P_E_not_H = 0.5  # Probabilidad de un falso positivo

# %% [markdown]
# <h1>Establecemos los numeros de tests realizados<h1>

# %%
tests = 3

# %% [markdown]
# <h1>Creamos una lista para almacenar las probalidades que vamos a tener<h1>

# %%
probabilities = [P_H]

# %% [markdown]
# <h1>Vamos a calcular los resultados de los embarazos, utilizando el teorema de Bayes<h1>

# %%
for _ in range(1, tests + 1):
    # Probabilidad complementaria
    P_not_H = 1 - P_H

    # Aplicar el Teorema de Bayes
    P_H_E = (P_E_H * P_H) / ((P_E_H * P_H) + (P_E_not_H * P_not_H))

    # Actualizar P(H) para el siguiente test
    P_H = P_H_E
    probabilities.append(P_H)

# %% [markdown]
# <h1>Monstramos los  resultados de los embarazos con un grafico<h1>

# %%
for i, prob in enumerate(probabilities):
    print(f"Después de {i} test(s) positivo(s), P(H|E) = {prob * 100:.2f}%")

# Graficar la evolución de las probabilidades
plt.figure(figsize=(8, 5))
plt.plot(range(len(probabilities)), [p * 100 for p in probabilities], marker='o', linestyle='-', color='blue')
plt.title('Evolución de la probabilidad de embarazo tras tests positivos')
plt.xlabel('Número de tests positivos')
plt.ylabel('Probabilidad de estar embarazada (%)')
plt.grid()
plt.show()
# Out:
# Después de 0 test(s) positivo(s), P(H|E) = 15.00%
# Después de 1 test(s) positivo(s), P(H|E) = 24.11%
# Después de 2 test(s) positivo(s), P(H|E) = 36.38%
# Después de 3 test(s) positivo(s), P(H|E) = 50.72%
