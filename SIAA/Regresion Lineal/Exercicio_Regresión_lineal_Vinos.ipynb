# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# Cargar dataset
wine_dataset = pd.read_csv('C:/Users/constantin.madalin.i/Desktop/Tareas-y-Ejercicios-de-Clase/SIAA/Regresion Lineal/winequality-red.csv')

# Seleccionar solo las columnas "alcohol" y "quality"
wine_dataset = wine_dataset[['alcohol', 'quality']]

# Ver las primeras filas para entender los datos
print(wine_dataset.head())

# Definir variables (X = "alcohol", y = "quality")
X = wine_dataset.iloc[:, :-1].values  # "alcohol"
y = wine_dataset.iloc[:, -1].values   # "quality"

# Dividir en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# Entrenar el modelo de Regresión Lineal
regressor = LinearRegression()
regressor.fit(X_train, y_train)

# Mostrar coeficientes
print("b0 (Intercepto):", regressor.intercept_)
print("b1 (Coeficientes):", regressor.coef_)

# Predicciones en el conjunto de prueba
y_pred = regressor.predict(X_test)

# Predicción con nuevos valores (ejemplo con valores promedio del dataset)
nuevas_muestras = np.mean(X_train, axis=0).reshape(1, -1)
prediccion_nueva = regressor.predict(nuevas_muestras)
print("Predicción para una nueva muestra promedio:", prediccion_nueva[0])

# Visualización: Relación entre alcohol y calidad del vino
plt.scatter(X_train, y_train, color='red', label="Datos reales")
plt.plot(X_train, regressor.predict(X_train), color='blue', label="Línea de regresión")
plt.title('Calidad vs Alcohol')
plt.xlabel('Alcohol')
plt.ylabel('Calidad')
plt.legend()
plt.show()
# Out:
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5
# b0 (Intercepto): 1.9289173025860098
# b1 (Coeficientes): [0.35759712]
# Predicción para una nueva muestra promedio: 5.651474530831099
